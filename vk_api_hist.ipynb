# %% [markdown]
# ## Install libs

# %%
#import standart package
import sys
import os
import re
import pandas as pd
import numpy as np
import requests

from matplotlib import pyplot as plt
from matplotlib import style
style.use('ggplot')
# %matplotlib inline

import warnings
warnings.simplefilter("ignore")

# %%
#import library in order to work with vk api
# !{sys.executable} -m pip install vk_api
import vk_api
# Out:
# Requirement already satisfied: vk_api in /usr/local/lib/python3.5/dist-packages
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from vk_api)
# Requirement already satisfied: enum34 in /usr/local/lib/python3.5/dist-packages (from vk_api)

# %%
#import library in order to work with hedden password
import getpass

# %%
#import library in order to work with progress bar
# !{sys.executable} -m pip install tqdm
from tqdm import tqdm_notebook as tqdm
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.5/dist-packages

# %%
#import library in order to work with graph
# !{sys.executable} -m pip install python-louvain
import community
import networkx as nx
# Out:
# Requirement already satisfied: python-louvain in /usr/local/lib/python3.5/dist-packages
# Requirement already satisfied: networkx in /usr/local/lib/python3.5/dist-packages (from python-louvain)
# Requirement already satisfied: decorator>=4.1.0 in /home/nikita/.local/lib/python3.5/site-packages (from networkx->python-louvain)

# %%
#import library in order to work with web-sraping
# !{sys.executable} -m pip install beautifulsoup4
from bs4 import BeautifulSoup as bs
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.5/dist-packages

# %%
#!conda install -c anaconda -y -p {sys.prefix} basemap
from mpl_toolkits.basemap import Basemap

# %%
print('If you want to make html version of your map, say \'yes\', else \'no\'')
IS_INSTAL = input()
#import library in order to work with web-sraping
if IS_INSTAL == 'yes':
    # !{sys.executable} -m pip install folium
    import folium
else:
    print('OK, it is your choice')
# Out:
# If you want to make html version of your map, say 'yes', else 'no'
# no
# OK, it is your choice

# %% [markdown]
# ## Connect to VK api

# %%
print("Please, enter your vk login:")
login = input()
password = getpass.getpass("Enter your password (hidden):")
# Out:
# Please, enter your vk login:
# 79151492105
# Enter your password (hidden):········

# %%
def captcha_handler(captcha):
    url = captcha.get_url()
    print(url)
    webbrowser.open(url, new = 2)
    key = input("Enter captcha code: ").strip()
    return captcha.try_again(key)

# %%
def auth_handler():
    key = input("Enter authentication code: ")
    remember_device = False
    return key, remember_device

# %%
vk = vk_api.VkApi(login, password,
                  captcha_handler = captcha_handler, auth_handler=auth_handler)  

try:
    vk.auth()
except vk_api.exceptions.BadPassword:
    print("Username or password is incorrect! \nPlese enter login again:")
    login = input()
    password = getpass.getpass("Enter your password again (hidden):")
    vk = vk_api.VkApi(login, password,
                      captcha_handler = captcha_handler, auth_handler=auth_handler)
    vk.auth()
except vk_api.exceptions.AccessDenied:
    raise ValueError("No access")
except:
    raise ValueError("Something wrong! Check everything")

# %%
#user_id = 'nick_1963'
user_id = 'val.shishkov'
my_info = vk.method('users.get', {'user_ids': user_id, 'fields':'bdate'})

user_id = my_info[0]['id']
my_info
# Out:
# [{'bdate': '6.4',
#   'first_name': 'Валентин',
#   'id': 146770615,
#   'last_name': 'Шишков'}]

# %% [markdown]
# ## Collect friends's information

# %%
def make_info(info):
    nan = np.nan
    size = len(info)
    data = {
        'users_id' : list(map(lambda i: int(info[i]['id']) if 'id' in info[i] else nan, range(size))), 
        'sex_id' : list(map(lambda i: int(info[i]['sex']) if 'sex' in info[i] else nan, range(size))),
        'first_name' : list(map(lambda i: info[i]['first_name'] if 'first_name' in info[i] else nan, range(size))),
        'last_name' : list(map(lambda i: info[i]['last_name'] if 'last_name' in info[i] else nan, range(size))),
        'city_id' : list(map(lambda i: int(info[i]['city']['id']) if 'city' in info[i] and 'id' in info[i]['city'] else nan, range(size))),
        'city_name' : list(map(lambda i: info[i]['city']['title'] if 'city' in info[i] and 'title' in info[i]['city'] else nan, range(size))),
        'home_name' : list(map(lambda i: info[i]['home_town'] if 'home_town' in info[i] else nan, range(size))),
        'univer_id' : list(map(lambda i: int(info[i]['universities'][0]['id']) if 'universities' in info[i] and len(info[i]['universities'])>1 else nan, range(size))),
        'univer_name' : list(map(lambda i: info[i]['universities'][0]['name'] if 'universities' in info[i] and len(info[i]['universities'])>1 else nan, range(size))),
        'school_id' : list(map(lambda i: int(info[i]['schools'][0]['id']) if 'schools' in info[i] and len(info[i]['schools'])>1 else nan, range(size))),
        'school_name' : list(map(lambda i: info[i]['schools'][0]['name'] if 'schools' in info[i] and len(info[i]['schools'])>1 else nan, range(size))),
        'occupt_id' : list(map(lambda i: int(info[i]['occupation']['id']) if 'occupation' in info[i] and 'id' in info[i]['occupation'] else nan, range(size))),
        'occupt_name' : list(map(lambda i: info[i]['occupation']['name'] if 'occupation' in info[i] and 'name' in info[i]['occupation'] else nan, range(size))),
        'occupt_type' : list(map(lambda i: info[i]['occupation']['type'] if 'occupation' in info[i] and 'type' in info[i]['occupation'] else nan, range(size))),
        'bd_year_id' : list(map(lambda i: int(info[i]['bdate'].split(r'.')[2]) if 'bdate' in info[i] and len(info[i]['bdate'].split(r'.'))>2 else nan, range(size))),
        'bd_mont_id' : list(map(lambda i: int(info[i]['bdate'].split(r'.')[1]) if 'bdate' in info[i] else nan, range(size))),
        'bd_day_id' : list(map(lambda i: int(info[i]['bdate'].split(r'.')[0]) if 'bdate' in info[i] else nan, range(size)))
    }
    
    df_info = pd.DataFrame(data=data)
    return df_info

def make_comm(user_id, friends_list):
    
    if 'comm_{}.csv'.format(user_id) in os.listdir("info_user_id"):
        df_comm = pd.read_csv('info_user_id/comm_{}.csv'.format(user_id))
        df_comm.set_index('users_id', inplace=True)
        df_comm.columns = list(map(lambda ind: int(ind), df_comm.columns))
    else:
        df_comm = pd.DataFrame(columns=friends_list)
        df_comm['users_id'] = friends_list
        df_comm.set_index('users_id', inplace=True)
        for idx in tqdm(friends_list):
            try: 
                frx = vk.method('friends.get', {'user_id':idx})['items']
                col = np.unique(list(map(lambda fr: fr if fr in friends_list else 0, frx)))
                col = np.delete(col, 0)
                df_comm.loc[idx][col] = 1
            except:
                print('User {} was deleted'.format(idx))

        df_comm.replace(np.nan, 0, inplace=True)
        df_comm.to_csv('info_user_id/comm_{}.csv'.format(user_id))
    return df_comm

def make_city(user_id, friends_list):
    
    if 'city_{}.csv'.format(user_id) in os.listdir("info_user_id"):
        df_city = pd.read_csv('info_user_id/city_{}.csv'.format(user_id), index_col=0)
    else:
        print('You have {} friends. How many friends can I choose:'.format(len(friends_list)))
        friends_num = int(input())
        friends_list = friends_list[:friends_num]
        
        friends_friends_list = [friends_list]
        for friend in tqdm(friends_list):
            try: 
                friends_list_i = vk.method('friends.get', {'user_id': friend})['items']
                friends_friends_list.append(friends_list_i)
            except:
                print('User {} was deleted'.format(friend))
        
        friends_friends_list = np.unique(np.concatenate(friends_friends_list)).tolist()
        max_size = 999
        df_city = pd.DataFrame(columns=['city_name'])
        for friends_slice in tqdm([friends_friends_list[i*max_size : (i+1)*max_size] \
                                   for i in range(int(len(friends_friends_list)/max_size)+1)]):
            
            friends_str = str(friends_slice)[1:][:-1]
            info = vk.method('users.get', {'user_ids': friends_str,
                                            'fields': 'city'})
            nan = np.nan
            size = len(info)
            data = {
                'city_name': list(map(lambda i: info[i]['city']['title'] if 'city' in info[i] and 'title' in info[i]['city'] else nan, range(size))),
            }

            df_city_x = pd.DataFrame(data)
            df_city = pd.concat([df_city, df_city_x])
            
        df_city = df_city['city_name'].value_counts().reset_index()
        df_city.columns = ['city_name', 'count']
        df_city.to_csv('info_user_id/city_{}.csv'.format(user_id))
    return df_city

def build_friends(user_id):
    try:
        friends_list = vk.method('friends.get', {'user_id': user_id})['items']
    except:
        vk = vk_api.VkApi(login, password,
                  captcha_handler = captcha_handler, auth_handler=auth_handler)
        vk.auth()
        friends_list = vk.method('friends.get', {'user_id': user_id})['items']
    
    friends_str = str([user_id] + friends_list)[1:][:-1]
    info = vk.method('users.get', {'user_ids': friends_str,
                                   'fields': 'city, bdate, home_town, occupation, schools, sex, universities'})
    
    try:
        os.stat('info_user_id')
    except:
        os.mkdir('info_user_id')
    print('Just second, collect information of your friends')
    df_info = make_info(info)
    print('One moment, collect information of friendships')
    df_comm = make_comm(user_id, friends_list)
    print('Almost end, colletc information of friends\'s friends\'s cities')
    df_city = make_city(user_id, friends_list)
    
    return df_info, df_comm, df_city

# %%
df_info, df_comm, df_city = build_friends(user_id)
# Out:
# Just second, collect information of your friends
# One moment, collect information of friendships
# Almost end, colletc information of friends's friends's cities

# %%
df_info.head()
# Out:
#    bd_day_id  bd_mont_id  bd_year_id  city_id city_name first_name home_name  \
# 0        6.0         4.0         NaN      1.0    Москва   Валентин    Москва
# 1       14.0         8.0         NaN      1.0    Москва       Анна
# 2       23.0         6.0         NaN      1.0    Москва    Евгений       NaN
# 3        9.0         4.0      1992.0      1.0    Москва    Дмитрий       NaN
# 4        NaN         NaN         NaN      NaN       NaN    DELETED       NaN
#
#    last_name  occupt_id                             occupt_name occupt_type  \
# 0     Шишков    11571.0                                     РЭШ  university
# 1  Тюменцева     1859.0                                   МосГУ  university
# 2    Соколов      289.0  МПГУ (бывш. МГПИ им. Ленина) (до 2015)  university
# 3    Сорокин      128.0                        НИУ ВШЭ (ГУ-ВШЭ)  university
# 4                   NaN                                     NaN         NaN
#
#    school_id school_name  sex_id  univer_id univer_name   users_id
# 0        NaN         NaN       2    11571.0         РЭШ  146770615
# 1        NaN         NaN       1     1859.0       МосГУ     388733
# 2        NaN         NaN       2        NaN         NaN     809452
# 3        NaN         NaN       2        NaN         NaN    1211407
# 4        NaN         NaN       2        NaN         NaN    1398749

# %%
df_city.shape
# Out:
# (565, 2)

# %% [markdown]
# ## Make and clustering graph

# %%
adj_matrix = df_comm.as_matrix()
friends_list = df_comm.index.tolist()
adj_matrix.shape
# Out:
# (302, 302)

# %%
#Delete removed users
ind = np.arange(adj_matrix.shape[0])[adj_matrix.sum(axis=1) < 3]
adj_matrix = np.delete(adj_matrix, ind, 0)
adj_matrix = np.delete(adj_matrix, ind, 1)
friends_list = np.delete(friends_list, ind, 0)
adj_matrix.shape, len(friends_list)
# Out:
# ((243, 243), 243)

# %%
G = nx.from_numpy_matrix(adj_matrix)
G_dend = community.generate_dendrogram(G)
parts = community.partition_at_level(G_dend,0)
comm_id = [parts.get(node) for node in G.nodes()]
pos = nx.spring_layout(G, iterations=150)
fig = plt.figure(figsize=(9, 9))
nx.draw_networkx(G, pos = pos, node_color = comm_id,
                 node_size = 50, with_labels = False,
                 width=0.6, edge_color ='silver')
plt.axis("off")
plt.show()

# %% [markdown]
# ### Bar plots

# %%
df_info
# Out:
#      bd_day_id  bd_mont_id  bd_year_id  city_id   city_name  first_name  \
# 0          6.0         4.0         NaN      1.0      Москва    Валентин
# 1         14.0         8.0         NaN      1.0      Москва        Анна
# 2         23.0         6.0         NaN      1.0      Москва     Евгений
# 3          9.0         4.0      1992.0      1.0      Москва     Дмитрий
# 4          NaN         NaN         NaN      NaN         NaN     DELETED
# 5         19.0        12.0      1986.0      1.0      Москва     Наталья
# 6         24.0         1.0         NaN      1.0      Москва      Stepan
# 7         17.0         6.0         NaN      1.0      Москва     Татьяна
# 8         10.0        11.0      1992.0      1.0      Москва        Анна
# 9         15.0         5.0      1993.0      1.0      Москва        Anna
# 10        27.0         3.0      1986.0      1.0      Москва   Александр
# 11        24.0        12.0         NaN      1.0      Москва     Наталья
# 12         8.0         3.0         NaN      1.0      Москва     Наталья
# 13        29.0         7.0         NaN     78.0      Липецк      Андрей
# 14         8.0         3.0         NaN      1.0      Москва   Александр
# 15         4.0         5.0      1995.0      1.0      Москва        Пётр
# 16        27.0         3.0      1991.0      1.0      Москва      Виктор
# 17         1.0         7.0         NaN      1.0      Москва      Андрей
# 18        18.0         1.0         NaN     66.0       Киров       Danil
# 19         NaN         NaN         NaN      1.0      Москва       Света
# 20         6.0        12.0         NaN      1.0      Москва   Анастасия
# 21         NaN         NaN         NaN      NaN         NaN     DELETED
# 22        23.0        11.0      1994.0      1.0      Москва       Антон
# 23        28.0        11.0         NaN      1.0      Москва        Егор
# 24         8.0         2.0      1994.0      1.0      Москва      Полина
# 25        23.0        11.0         NaN      1.0      Москва       Давид
# 26         NaN         NaN         NaN      1.0      Москва      Андрей
# 27        19.0        10.0         NaN      1.0      Москва   Елизавета
# 28         9.0         8.0      1981.0    110.0       Пермь    Владимир
# 29        13.0         7.0      1995.0      NaN         NaN        Анна
# ..         ...         ...         ...      ...         ...         ...
# 273        9.0         4.0      1998.0      1.0      Москва       Игорь
# 274       20.0         7.0      1982.0      NaN         NaN     Алексей
# 275        1.0        10.0         NaN      1.0      Москва        Илья
# 276        NaN         NaN         NaN      1.0      Москва     Тимофей
# 277        NaN         NaN         NaN     60.0      Казань      Рамиль
# 278        NaN         NaN         NaN      NaN         NaN         Оля
# 279        9.0         7.0         NaN      1.0      Москва        Даша
# 280        NaN         NaN         NaN      NaN         NaN      Марина
# 281        NaN         NaN         NaN      1.0      Москва      Оксана
# 282        NaN         NaN         NaN      NaN         NaN       Мария
# 283        NaN         NaN         NaN      NaN         NaN      Сергей
# 284        NaN         NaN         NaN      NaN         NaN        Мага
# 285        1.0         7.0         NaN      1.0      Москва      Парвин
# 286       14.0         1.0      1988.0      1.0      Москва       Семён
# 287        NaN         NaN         NaN      NaN         NaN        Кира
# 288        NaN         NaN         NaN      NaN         NaN       Г-О-А
# 289       17.0         2.0      1948.0      1.0      Москва    Алефтина
# 290        NaN         NaN         NaN      NaN         NaN      Лариса
# 291        NaN         NaN         NaN      NaN         NaN    Алиночка
# 292        NaN         NaN         NaN      NaN         NaN       Данил
# 293        NaN         NaN         NaN      NaN         NaN        Влад
# 294        NaN         NaN         NaN      NaN         NaN   Анастасия
# 295       10.0         3.0         NaN      1.0      Москва      Марина
# 296       13.0         3.0         NaN      1.0      Москва       Outer
# 297        1.0         8.0      1995.0      NaN         NaN        Basy
# 298        4.0         1.0         NaN   6181.0  Московский     Виталий
# 299       24.0         8.0      1997.0      1.0      Москва       Артём
# 300        2.0        12.0      1991.0      NaN         NaN   Екатерина
# 301        NaN         NaN         NaN      1.0      Москва   Neskuchny
# 302        NaN         NaN         NaN      1.0      Москва  Александра
#
#     home_name    last_name    occupt_id  \
# 0      Москва       Шишков      11571.0
# 1                Тюменцева       1859.0
# 2         NaN      Соколов        289.0
# 3         NaN      Сорокин        128.0
# 4         NaN                       NaN
# 5      Москва     Ивликова          NaN
# 6         NaN     Mayserik      11571.0
# 7         NaN     Лобачева          NaN
# 8     Ташкент     Новикова  141794937.0
# 9         NaN       Donnik   41681954.0
# 10        NaN  Челеховский          NaN
# 11        NaN      Типсина        128.0
# 12    Елабуга       Чекина        239.0
# 13     Липецк     Корчагин        607.0
# 14     Москва   Рублевский       1070.0
# 15        NaN     Мартынов    1039546.0
# 16        NaN     Дорофеев        304.0
# 17        NaN      Зубенко        236.0
# 18        NaN     Yakovlev        128.0
# 19        NaN          Тен          NaN
# 20        NaN       Лукина        128.0
# 21        NaN                       NaN
# 22        NaN       Трусов      11571.0
# 23        NaN       Иванов   55430596.0
# 24     Москва  Виноградова  152683594.0
# 25        NaN     Геворгян        128.0
# 26        NaN      Сафонов          NaN
# 27    Иваново   Грушанская      11571.0
# 28      Пермь      Ефремов  150817479.0
# 29        NaN    Хоруженко          NaN
# ..        ...          ...          ...
# 273       NaN       Карпов      11571.0
# 274                Тарасов          2.0
# 275       NaN           Вд        106.0
# 276       NaN     Кунцевич   84652836.0
# 277       NaN        Сафин          NaN
# 278       NaN     Арбенина          NaN
# 279              Васильева   70970877.0
# 280       NaN    Скварцова          NaN
# 281    Москва    Василенко          NaN
# 282       NaN       Речина          NaN
# 283       NaN     Кальянов          NaN
# 284       NaN         Мага          NaN
# 285       NaN      Тагиева        128.0
# 286   Грозный      Вакабов          NaN
# 287       NaN          Син          NaN
# 288       NaN    Краснодар          NaN
# 289    Москва   Алексеевна          NaN
# 290       NaN     Красевич          NaN
# 291       NaN    Скворцова          NaN
# 292       NaN         Юрич          NaN
# 293       NaN       Куимов          NaN
# 294       NaN    Кравченко          NaN
# 295    Москва    Самойлова  127872751.0
# 296       NaN        Space          NaN
# 297                   Chow        128.0
# 298    Москва     Соловьев          NaN
# 299                  Сенин        128.0
# 300                Глебова          NaN
# 301    Москва     Crossfit          NaN
# 302       NaN    Стукалова          NaN
#
#                                    occupt_name occupt_type  school_id  \
# 0                                          РЭШ  university        NaN
# 1                                        МосГУ  university        NaN
# 2       МПГУ (бывш. МГПИ им. Ленина) (до 2015)  university        NaN
# 3                             НИУ ВШЭ (ГУ-ВШЭ)  university        NaN
# 4                                          NaN         NaN        NaN
# 5                                           EY        work     4902.0
# 6                                          РЭШ  university        NaN
# 7                                          NaN         NaN        NaN
# 8                    Искусство маленьких шагов        work     7030.0
# 9                      Anna Donnik Photography        work        NaN
# 10                                     НИУ ВШЭ        work        NaN
# 11                            НИУ ВШЭ (ГУ-ВШЭ)  university        NaN
# 12                                  НИТУ МИСиС  university     7865.0
# 13        ЛГПУ им. П. П. Семенова-Тян-Шанского  university        NaN
# 14                                        РГСУ  university        NaN
# 15         University of California - Berkeley  university        NaN
# 16                                     НИУ МЭИ  university        NaN
# 17                            МГИМО МИД России  university        NaN
# 18                            НИУ ВШЭ (ГУ-ВШЭ)  university        NaN
# 19                                         NaN         NaN        NaN
# 20                            НИУ ВШЭ (ГУ-ВШЭ)  university        NaN
# 21                                         NaN         NaN        NaN
# 22                                         РЭШ  university        NaN
# 23   ANTEGO Event | Агентство Ключевых Событий        work        NaN
# 24                           Vinogradova Event        work        NaN
# 25                            НИУ ВШЭ (ГУ-ВШЭ)  university        NaN
# 26                                         NaN         NaN        NaN
# 27                                         РЭШ  university        NaN
# 28                НАСЛЕДИЕ 21 Бизнес-ШОУ Пермь        work     9029.0
# 29                                         NaN         NaN        NaN
# ..                                         ...         ...        ...
# 273                                        РЭШ  university        NaN
# 274                                        МГУ  university        NaN
# 275             ВУМО РФ (бывш. ВПА им. Ленина)  university        NaN
# 276                               Pluses Media        work        NaN
# 277                                        NaN         NaN        NaN
# 278                                        NaN         NaN        NaN
# 279                               History Time        work        NaN
# 280                                        NaN         NaN        NaN
# 281                                        NaN         NaN        NaN
# 282                                        NaN         NaN        NaN
# 283                                        NaN         NaN        NaN
# 284                                        NaN         NaN        NaN
# 285                           НИУ ВШЭ (ГУ-ВШЭ)  university        NaN
# 286                                        NaN         NaN        NaN
# 287                                        NaN         NaN        NaN
# 288                                        NaN         NaN        NaN
# 289                                        NaN         NaN        NaN
# 290                                        NaN         NaN        NaN
# 291                                        NaN         NaN        NaN
# 292                                        NaN         NaN        NaN
# 293                                        NaN         NaN        NaN
# 294                                        NaN         NaN        NaN
# 295                              Москва Работа        work        NaN
# 296                                        NaN         NaN        NaN
# 297                           НИУ ВШЭ (ГУ-ВШЭ)  university        NaN
# 298                            Предприниматель        work        NaN
# 299                           НИУ ВШЭ (ГУ-ВШЭ)  university        NaN
# 300                                        NaN         NaN        NaN
# 301                                        NaN         NaN        NaN
# 302                                        NaN         NaN        NaN
#
#      school_name  sex_id  univer_id                           univer_name  \
# 0            NaN       2    11571.0                                   РЭШ
# 1            NaN       1     1859.0                                 МосГУ
# 2            NaN       2        NaN                                   NaN
# 3            NaN       2        NaN                                   NaN
# 4            NaN       2        NaN                                   NaN
# 5     Школа №898       1        2.0                                   МГУ
# 6            NaN       2        NaN                                   NaN
# 7            NaN       1        NaN                                   NaN
# 8    Школа №1319       1      128.0                      НИУ ВШЭ (ГУ-ВШЭ)
# 9            NaN       1        NaN                                   NaN
# 10           NaN       2        NaN                                   NaN
# 11           NaN       1        NaN                                   NaN
# 12      Школа №2       1        NaN                                   NaN
# 13           NaN       2      607.0  ЛГПУ им. П. П. Семенова-Тян-Шанского
# 14           NaN       2        NaN                                   NaN
# 15           NaN       2        NaN                                   NaN
# 16           NaN       2        NaN                                   NaN
# 17           NaN       2        NaN                                   NaN
# 18           NaN       2        NaN                                   NaN
# 19           NaN       1        NaN                                   NaN
# 20           NaN       1        NaN                                   NaN
# 21           NaN       1        NaN                                   NaN
# 22           NaN       2        NaN                                   NaN
# 23           NaN       2        NaN                                   NaN
# 24           NaN       1        NaN                                   NaN
# 25           NaN       2        NaN                                   NaN
# 26           NaN       2        NaN                                   NaN
# 27           NaN       1        NaN                                   NaN
# 28    Школа №134       2        NaN                                   NaN
# 29           NaN       1        NaN                                   NaN
# ..           ...     ...        ...                                   ...
# 273          NaN       2        NaN                                   NaN
# 274          NaN       2        NaN                                   NaN
# 275          NaN       2        NaN                                   NaN
# 276          NaN       2        NaN                                   NaN
# 277          NaN       2        NaN                                   NaN
# 278          NaN       1        NaN                                   NaN
# 279          NaN       1        NaN                                   NaN
# 280          NaN       1        NaN                                   NaN
# 281          NaN       1        NaN                                   NaN
# 282          NaN       1        NaN                                   NaN
# 283          NaN       2        NaN                                   NaN
# 284          NaN       2        NaN                                   NaN
# 285          NaN       1        NaN                                   NaN
# 286          NaN       2        NaN                                   NaN
# 287          NaN       1        NaN                                   NaN
# 288          NaN       1        NaN                                   NaN
# 289          NaN       1        NaN                                   NaN
# 290          NaN       1        NaN                                   NaN
# 291          NaN       1        NaN                                   NaN
# 292          NaN       2        NaN                                   NaN
# 293          NaN       2        NaN                                   NaN
# 294          NaN       1        NaN                                   NaN
# 295          NaN       1        NaN                                   NaN
# 296          NaN       1        NaN                                   NaN
# 297          NaN       1      128.0                      НИУ ВШЭ (ГУ-ВШЭ)
# 298          NaN       2        NaN                                   NaN
# 299          NaN       2        NaN                                   NaN
# 300          NaN       1        NaN                                   NaN
# 301          NaN       2        NaN                                   NaN
# 302          NaN       1        NaN                                   NaN
#
#       users_id
# 0    146770615
# 1       388733
# 2       809452
# 3      1211407
# 4      1398749
# 5      1462897
# 6      1496469
# 7      1847433
# 8      2164591
# 9      2254772
# 10     2543380
# 11     2547497
# 12     2782638
# 13     2787597
# 14     4343441
# 15     4567963
# 16     4745108
# 17     5002520
# 18     5238729
# 19     5327079
# 20     5492385
# 21     6088333
# 22     6583313
# 23     6625510
# 24     6670849
# 25     6934546
# 26     7073813
# 27     7291204
# 28     7334040
# 29     7614322
# ..         ...
# 273  290347902
# 274  292720041
# 275  297559778
# 276  300080813
# 277  300330659
# 278  301649063
# 279  301925169
# 280  306138854
# 281  306501125
# 282  310578809
# 283  313022862
# 284  318786522
# 285  319266898
# 286  324041219
# 287  325894900
# 288  330648745
# 289  331749519
# 290  333782276
# 291  336249359
# 292  352314457
# 293  365759811
# 294  367418236
# 295  369527114
# 296  370360497
# 297  377551467
# 298  391477759
# 299  393326652
# 300  395377249
# 301  408365511
# 302  416183130
#
# [303 rows x 17 columns]

# %%
col = 'city_name'

df_bar = pd.DataFrame(index=df_info[col].dropna().unique())

for comm in df_info['comm_id'].dropna().unique():

    ind = df_info[df_info['comm_id'] == comm][col].dropna().value_counts().index
    count = df_info[df_info['comm_id'] == comm][col].dropna().value_counts().as_matrix()
    ind = ind[count >= 2]
    count = count[count >= 2]
    df_bar[comm] = 0
    df_bar[comm].loc[ind] = count

df_bar.drop(df_bar.index[df_bar.sum(axis=1) == 0], inplace=True)



fig, ax = plt.subplots(1, 1, figsize=(15, 4))
width = 0.9/len(df_bar.columns)
ind = df_bar[comm].index
size = len(ind)

for comm in df_bar.columns:
    count = df_bar[comm].as_matrix()
    ax.bar(comm * width + np.arange(size), count, width, alpha=0.8, label=str(comm+1)+'st')

ax.set_xticks(np.arange(size))
ax.set_xticklabels(df_bar.index, rotation = 90)
ax.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.5/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'comm_id'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-fcf58efdfa02> in <module>()
#       3 df_bar = pd.DataFrame(index=df_info[col].dropna().unique())
#       4
# ----> 5 for comm in df_info['comm_id'].dropna().unique():
#       6
#       7     ind = df_info[df_info['comm_id'] == comm][col].dropna().value_counts().index
#
# ~/.local/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# ~/.local/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# ~/.local/lib/python3.5/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# ~/.local/lib/python3.5/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~/.local/lib/python3.5/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'comm_id'

# %%
df_bar_sex = df_info.loc[:,'sex_id'].to_frame()
df_bar_sex = df_bar_sex.replace(to_replace = {'sex_id':{2:'male',1:'female'}})['sex_id'].value_counts()
df_bar_sex.plot.bar()

# %%
df_bar_school = df_info.loc[:,'school_name'].to_frame()
frequency = df_bar_school['school_name'].value_counts()
removing = frequency[frequency <= 1].index
df_bar_school['school_name'].loc[df_bar_school['school_name'].isin(removing)]=np.nan    
df_bar_school.dropna(axis=0, how='any')['school_name'].value_counts().plot.bar()

# %%
def make_hist(df_info, df_comm, comm_id, friends_list):
    #Make new columns
    df_info['comm_id'] = None
    df_info.set_index('users_id', inplace=True)
    df_info['comm_id'].loc[friends_list] = comm_id
    df_info.reset_index(inplace=True)
    
    columns = ['city_id', 'occupt_id', 'school_id', 'sex_id', 'univer_id']
    f, ax = plt.subplots(len(columns), 1, figsize=(15, 4*len(columns)))
        
    for i, col in enumerate(columns):    
        ax[i].set_title(col)
        data = []
        labels = []
        for comm in df_info['comm_id'].dropna().unique():
            data.append(df_info[df_info['comm_id'] == comm][col].dropna())
            labels.append(str(comm+1) + 'st community')
        
        ax[i].hist(data, bins=20, alpha=0.8, label=labels)
        ax[i].legend()
    
    plt.show()

# %%
make_hist(df_info, df_comm, comm_id, friends_list)

# %%
def look_people():
    print('You have {} community'.format(df_info['comm_id'].dropna().unique().max() + 1))
    print('Enter a number of community')
    comm = input()
    try:
        comm = int(comm)
        if comm in df_info['comm_id'].dropna().unique():
            print('Look at people in this community')
            com_users_id = df_info[df_info['comm_id'] == comm]['users_id'].as_matrix()
            #df = df_comm.loc[com_users_id][com_users_id]
            #adj = df.as_matrix()
            #ind = adj.sum(axis=1).argsort()[-5:][::-1]
            #ind = df.reset_index()['users_id'][ind].as_matrix()
            df_info.set_index('users_id', inplace=True)
            for i in com_users_id:
                print('\t{} {}'.format(df_info.loc[i]['first_name'], df_info.loc[i]['last_name']))
            df_info.reset_index('users_id', inplace=True)
        else:
            print('Sorry, you have not commuity with this number')
    except:
        print('Sorry, enter a number')

# %%
look_people()
# Out:
# You have 7 community
# Enter a number of community

# %% [markdown]
# ## Make map of your frends

# %%
def make_cord_city(df):

    df.set_index('city_name', inplace=True)
    df['lat'] = np.nan
    df['lon'] = np.nan
    for city in tqdm(df.index):
        ADD_CORD = False
        #Check Russian wikipedia
        if ADD_CORD == False:
            WIKI_URL = 'https://ru.wikipedia.org/wiki/' + str(city)
            req = requests.get(WIKI_URL)
            soup = bs(req.content, 'lxml')
            w = soup.find_all("script")[1]
            for split_text in re.split(r'[{}]', w.text):
                if 'lat' in split_text and 'lon' in split_text:
                    cord = re.split(r'[,:]', split_text)

                    try:
                        df['lat'][city] = float(cord[1])
                        df['lon'][city] = float(cord[3])
                        ADD_CORD = True
                    except:
                        None

                    
        if ADD_CORD == False:
            WIKI_URL = 'https://en.wikipedia.org/wiki/' + str(city)
            req = requests.get(WIKI_URL)
            soup = bs(req.content, 'lxml')
            w = soup.find_all("script")[1]
            for split_text in re.split(r'[{}]', w.text):
                if 'lat' in split_text and 'lon' in split_text:
                    cord = re.split(r'[,:]', split_text)
    
                    try:
                        df['lat'][city] = float(cord[1])
                        df['lon'][city] = float(cord[3])
                        ADD_CORD = True
                    except:
                        None
    
    df.reset_index(inplace=True)
    return df

# %%
df_city = make_cord_city(df_city)
# Out:
# HBox(children=(IntProgress(value=0, max=442), HTML(value='')))

# %%
### FROM:https://python-graph-gallery.com/315-a-world-map-of-surf-tweets/
 
my_dpi=300
plt.figure(figsize=(2600/my_dpi, 1800/my_dpi), dpi=my_dpi)
 
m=Basemap(llcrnrlon=-180, llcrnrlat=-65,urcrnrlon=180,urcrnrlat=80)
m.drawmapboundary(fill_color='#BBD7E8', linewidth=0)
m.fillcontinents(color='grey', alpha=0.5)
m.drawcoastlines(linewidth=0.1, color="white")
 
# Add a point per position
m.scatter(df_city['lon'], df_city['lat'],
          s= 2*np.sqrt(df_city['count']),
          c='r', alpha=0.4, cmap="Set1")
 
plt.text( -170, -58, 'City of friends\'s frineds of user_{}'.format(user_id),
         ha='left', va='bottom', size=5, color='#555555' )
 
# Save as png
plt.savefig('info_user_id/map_{}.png'.format(user_id), dpi = my_dpi, bbox_inches='tight')
plt.show()

### END FROM

# %%
try:
    ### FROM: https://python-graph-gallery.com/313-bubble-map-with-folium/
    m = folium.Map(location=[20,0], tiles="Mapbox Bright", zoom_start=2)

    data = df_city.dropna()
    # I can add marker one by one on the map
    for i in range(0,len(data)):
        folium.Circle(
            location=[data.iloc[i]['lat'], data.iloc[i]['lon']],
            popup=data.iloc[i]['city_name'],
            radius=np.sqrt(data.iloc[i]['count'])*1000.0,
            color='crimson',
            fill=True,
            fill_color='crimson').add_to(m)

    # Save it as html
    m.save('info_user_id/map_{}.html'.format(user_id))
    print('Open the file')
    ### END FROM
except:
    None
# Out:
# Open the file
